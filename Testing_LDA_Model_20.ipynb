# %%
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split


from modules import gbvoid_dataset as gbvoid
from modules import LDA_Model as LDA_model
from modules import cm_analysis as cm_analysis

# %%
# DATA

inputs = ['1_001', '1_002', '1_003', '1_004', '1_005', '1_006', '1_007', '1_008', '1_009', '1_010',
          '2_001', '2_002', '2_003', '2_004', '2_005', '2_006', '2_007', '2_008', '2_009',
          '3_001', '3_002', '3_003', '3_004', '3_005', '3_006', '3_007', '3_008', '3_009', '3_010',
          '4_001', '4_002', '4_003', '4_004', '4_005', '4_007', '4_008', '4_009',
          '5_001', '5_002', '5_003', '5_004', '5_005', '5_006', '5_007', '5_008', '5_009', '5_010', '5_011',
          '6_001', '6_002', '6_003', '6_004', '6_005', '6_006', '6_007', '6_008', '6_009']

columns_void=['phi1_right','PHI_right','phi2_right','phi1_left','PHI_left','phi2_left',
         'Misorientation Angle','Mis. X in Right Hand Grain','Mis. Y in Right Hand Grain', 'Mis. Z in Right Hand Grain',
         'Mis. X in Left Hand Grain','Mis. Y in Left Hand Grain','Mis. Z in Left Hand Grain',
         'Lenght','Trace', 'X start', 'Y start', 'X end','Y end','ID Right Grain', 'ID Left Grain', 'Void']

columns_drop=['ID Right Grain','ID Left Grain']

# Collect all txt data
data=[]
for name in inputs:
    void_dataset_temp = gbvoid.gbvoid_dataset(name)
    data.append(void_dataset_temp)
void_dataset=pd.concat(data, ignore_index='True')
void_dataset.columns=columns_void

# Drop ID grain form the dataset
void_dataset=void_dataset.drop(columns_drop, axis=1)

# %%
random_state_value=0
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=random_state_value)
df_train=X_train
df_train['Void']=y_train
X_lda, y, cm, y_test, y_pred=LDA_model.LDA_model(void_dataset,0)
print('\n')
print(X_lda)
# Out:
# CONFUSION MATRIX:
# [[48836     8]
#  [  482     0]]
# Accuracy: 0.9900660909054049
#
#
# Analytic Results:
# Recall score class 1: 0.999836213250348
# Recall score class 2: 0.0
# Precision class 1: 0.9902266920799708
# Precision class 2: 0.0
# Accuracy: 0.9900660909054049
#
#
# [[-0.04393123  0.01838756]
#  [-0.08507795 -0.04831047]
#  [-0.10550698 -0.05778602]
#  ...
#  [-0.17168344 -0.17697849]
#  [-0.1472245  -0.21966583]
#  [-0.08560367 -0.12132474]]

# %%
cm_analysis.cm_analysis(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     48844
#            1       0.00      0.00      0.00       482
#
#     accuracy                           0.99     49326
#    macro avg       0.50      0.50      0.50     49326
# weighted avg       0.98      0.99      0.99     49326

# %%
print(len(y_test))
print(lne())

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=1)
df_train=X_train
df_train['Void']=y_train
X_lda,y=LDA_model.LDA_model(df_train)
print(X_lda[:, 0])
print(X_lda[:, 1])
# Out:
# [-0.01135088 -0.08400353 -0.16283043 ... -0.04661563 -0.00812697
#  -0.11138689]
# [-0.25051192 -0.38345457 -0.31157306 ... -0.66322309  0.22515959
#  -0.96710994]

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=2)
df_train=X_train
df_train['Void']=y_train
X_lda,y,confusion_matrix=LDA_model.LDA_model(df_train)
print(confusion_matrix)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=3)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=4)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=5)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=6)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=7)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=8)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=9)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=10)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=11)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=12)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=13)
df_train=X_train
df_train['Void']=y_train
LDA_model.LDA_model(df_train)
