# %%
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split


from modules import gbvoid_dataset as gbvoid
from modules import LDA_Model as LDA_model

# %%
# DATA

inputs = ['1_001', '1_002', '1_003', '1_004', '1_005', '1_006', '1_007', '1_008', '1_009', '1_010',
          '2_001', '2_002', '2_003', '2_004', '2_005', '2_006', '2_007', '2_008', '2_009',
          '3_001', '3_002', '3_003', '3_004', '3_005', '3_006', '3_007', '3_008', '3_009', '3_010',
          '4_001', '4_002', '4_003', '4_004', '4_005', '4_007', '4_008', '4_009',
          '5_001', '5_002', '5_003', '5_004', '5_005', '5_006', '5_007', '5_008', '5_009', '5_010', '5_011',
          '6_001', '6_002', '6_003', '6_004', '6_005', '6_006', '6_007', '6_008', '6_009']

columns_void=['phi1_right','PHI_right','phi2_right','phi1_left','PHI_left','phi2_left',
         'Misorientation Angle','Mis. X in Right Hand Grain','Mis. Y in Right Hand Grain', 'Mis. Z in Right Hand Grain',
         'Mis. X in Right Hand Grain','Mis. Y in Right Hand Grain','Mis. Z in Right Hand Grain',
         'Lenght','Trace', 'X start', 'Y start', 'X end','Y end','ID Right Grain', 'ID Left Grain', 'Void']

columns_drop=['ID Right Grain','ID Left Grain']

# Collect all txt data
data=[]
for name in inputs:
    void_dataset_temp = gbvoid.gbvoid_dataset(name)
    data.append(void_dataset_temp)
void_dataset=pd.concat(data, ignore_index='True')
void_dataset.columns=columns_void

# Drop ID grain form the dataset
void_dataset=void_dataset.drop(columns_drop, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=15)
df_train=X_train
df_train['Void']=y_train
print(df_train)
LDA_model.LDA_model(df_train)
# Out:
#         phi1_right  PHI_right  phi2_right  phi1_left  PHI_left  phi2_left  \
# 68918        5.636      0.662       1.418      2.533     0.762      3.430
# 148630       3.840      0.190       2.626      1.570     0.647      4.022
# 142711       2.608      0.345       4.049      6.032     0.837      0.715
# 39885        4.573      0.669       1.644      4.905     0.206      1.821
# 153570       0.265      0.772       5.925      4.206     0.101      1.311
# ...            ...        ...         ...        ...       ...        ...
# 104832       2.980      0.675       3.538      3.823     0.928      2.269
# 180087       5.397      0.620       1.573      5.856     0.698      0.745
# 8076         2.638      0.615       3.885      4.365     0.248      1.863
# 184053       0.342      0.815       5.814      1.661     0.419      5.404
# 7624         1.485      0.055       4.498      1.945     0.176      4.415
#
#         Misorientation Angle  Mis. X in Right Hand Grain  \
# 68918                  22.84                       -19.0
# 148630                 59.65                        16.0
# 142711                 58.14                        19.0
# 39885                  38.92                        -5.0
# 153570                 59.86                        -1.0
# ...                      ...                         ...
# 104832                 52.29                         2.0
# 180087                 31.21                        -7.0
# 8076                   44.88                        -8.0
# 184053                 61.25                        19.0
# 7624                   22.71                         4.0
#
#         Mis. Y in Right Hand Grain  Mis. Z in Right Hand Grain  \
# 68918                          7.0                       -12.0
# 148630                        19.0                        14.0
# 142711                        19.0                        14.0
# 39885                        -10.0                       -11.0
# 153570                        -1.0                        -1.0
# ...                            ...                         ...
# 104832                        15.0                        15.0
# 180087                        -1.0                        11.0
# 8076                          11.0                         7.0
# 184053                       -10.0                       -18.0
# 7624                          -5.0                       -19.0
#
#         Mis. X in Right Hand Grain  Mis. Y in Right Hand Grain  \
# 68918                        -19.0                         7.0
# 148630                        16.0                        19.0
# 142711                        19.0                        19.0
# 39885                         -5.0                       -10.0
# 153570                        -1.0                        -1.0
# ...                            ...                         ...
# 104832                         2.0                        15.0
# 180087                        -7.0                        -1.0
# 8076                          -8.0                        11.0
# 184053                        19.0                       -10.0
# 7624                           4.0                        -5.0
#
#         Mis. Z in Right Hand Grain  Lenght  Trace  X start  Y start   X end  \
# 68918                        -12.0  41.905   11.9     15.0   558.30    56.0
# 148630                        14.0   4.163  136.1    397.0   827.34   400.0
# 142711                        14.0  13.317   85.7    843.0    87.18   844.0
# 39885                        -11.0  16.773   26.6   1231.0   131.06  1246.0
# 153570                        -1.0  21.385   70.9    883.0   707.25   890.0
# ...                            ...     ...    ...      ...      ...     ...
# 104832                        15.0  15.100  113.4    842.0   372.97   848.0
# 180087                        11.0  15.875  139.1    309.0   124.13   321.0
# 8076                           7.0  19.425   12.0    972.0    94.69   991.0
# 184053                       -18.0   8.083   90.0    127.0   176.09   127.0
# 7624                         -19.0   3.055  109.1    873.0   744.20   874.0
#
#          Y end  Void
# 68918   549.64   0.0
# 148630  830.23   0.0
# 142711   73.90   0.0
# 39885   123.55   0.0
# 153570  687.05   0.0
# ...        ...   ...
# 104832  386.82   0.0
# 180087  134.52   0.0
# 8076     90.64   0.0
# 184053  184.17   0.0
# 7624    747.09   0.0
#
# [177573 rows x 20 columns]
# Pairs:
# 19850810664.17789
# 1155041132.178031
# 537012875.6838046
# 21087285.625737295
# 241.97296110563477
# 241.97296110563477
# 58.47756999612569
# 58.47756999612569
# 32.59157906373282
# 32.589688688176565
# 5.2060732281845214e-05
# 4.657349469918312e-05
# 4.657349469918312e-05
# 1.550255296546391e-05
# 3.931306772438459e-06
# 3.931306772438459e-06
# 9.609618345188566e-07
# 8.204801167452957e-07
# 8.204801167452957e-07
# ------------------
# Explained Variance
# Eigenvector 0: -1.031003688109501
# Eigenvector 1: -0.0599900773494704
# Eigenvector 2: -0.027891165996127905
# Eigenvector 3: -0.00109522324403541
# Eigenvector 4: -1.2567497597107233e-08
# Eigenvector 5: -1.2567497597107233e-08
# Eigenvector 6: -3.037185299766395e-09
# Eigenvector 7: -3.037185299766395e-09
# Eigenvector 8: -1.6927287648084847e-09
# Eigenvector 9: -1.6926305832176477e-09
# Eigenvector 10: -2.7039100768374935e-15
# Eigenvector 11: -2.4189160642016883e-15
# Eigenvector 12: -2.4189160642016883e-15
# Eigenvector 13: -8.05165569955735e-16
# Eigenvector 14: -2.0418268301697948e-16
# Eigenvector 15: -2.0418268301697948e-16
# Eigenvector 16: -4.9910062227800945e-17
# Eigenvector 17: -4.2613777376428725e-17
# Eigenvector 18: -4.2613777376428725e-17

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.10, random_state=15)
df_train=X_train
df_train['Void']=y_train
print(df_train)
LDA_model.LDA_model(df_train)
# Out:
#         phi1_right  PHI_right  phi2_right  phi1_left  PHI_left  phi2_left  \
# 68918        5.636      0.662       1.418      2.533     0.762      3.430
# 148630       3.840      0.190       2.626      1.570     0.647      4.022
# 142711       2.608      0.345       4.049      6.032     0.837      0.715
# 39885        4.573      0.669       1.644      4.905     0.206      1.821
# 153570       0.265      0.772       5.925      4.206     0.101      1.311
# ...            ...        ...         ...        ...       ...        ...
# 104832       2.980      0.675       3.538      3.823     0.928      2.269
# 180087       5.397      0.620       1.573      5.856     0.698      0.745
# 8076         2.638      0.615       3.885      4.365     0.248      1.863
# 184053       0.342      0.815       5.814      1.661     0.419      5.404
# 7624         1.485      0.055       4.498      1.945     0.176      4.415
#
#         Misorientation Angle  Mis. X in Right Hand Grain  \
# 68918                  22.84                       -19.0
# 148630                 59.65                        16.0
# 142711                 58.14                        19.0
# 39885                  38.92                        -5.0
# 153570                 59.86                        -1.0
# ...                      ...                         ...
# 104832                 52.29                         2.0
# 180087                 31.21                        -7.0
# 8076                   44.88                        -8.0
# 184053                 61.25                        19.0
# 7624                   22.71                         4.0
#
#         Mis. Y in Right Hand Grain  Mis. Z in Right Hand Grain  \
# 68918                          7.0                       -12.0
# 148630                        19.0                        14.0
# 142711                        19.0                        14.0
# 39885                        -10.0                       -11.0
# 153570                        -1.0                        -1.0
# ...                            ...                         ...
# 104832                        15.0                        15.0
# 180087                        -1.0                        11.0
# 8076                          11.0                         7.0
# 184053                       -10.0                       -18.0
# 7624                          -5.0                       -19.0
#
#         Mis. X in Right Hand Grain  Mis. Y in Right Hand Grain  \
# 68918                        -19.0                         7.0
# 148630                        16.0                        19.0
# 142711                        19.0                        19.0
# 39885                         -5.0                       -10.0
# 153570                        -1.0                        -1.0
# ...                            ...                         ...
# 104832                         2.0                        15.0
# 180087                        -7.0                        -1.0
# 8076                          -8.0                        11.0
# 184053                        19.0                       -10.0
# 7624                           4.0                        -5.0
#
#         Mis. Z in Right Hand Grain  Lenght  Trace  X start  Y start   X end  \
# 68918                        -12.0  41.905   11.9     15.0   558.30    56.0
# 148630                        14.0   4.163  136.1    397.0   827.34   400.0
# 142711                        14.0  13.317   85.7    843.0    87.18   844.0
# 39885                        -11.0  16.773   26.6   1231.0   131.06  1246.0
# 153570                        -1.0  21.385   70.9    883.0   707.25   890.0
# ...                            ...     ...    ...      ...      ...     ...
# 104832                        15.0  15.100  113.4    842.0   372.97   848.0
# 180087                        11.0  15.875  139.1    309.0   124.13   321.0
# 8076                           7.0  19.425   12.0    972.0    94.69   991.0
# 184053                       -18.0   8.083   90.0    127.0   176.09   127.0
# 7624                         -19.0   3.055  109.1    873.0   744.20   874.0
#
#          Y end  Void
# 68918   549.64   0.0
# 148630  830.23   0.0
# 142711   73.90   0.0
# 39885   123.55   0.0
# 153570  687.05   0.0
# ...        ...   ...
# 104832  386.82   0.0
# 180087  134.52   0.0
# 8076     90.64   0.0
# 184053  184.17   0.0
# 7624    747.09   0.0
#
# [177573 rows x 20 columns]
# Pairs:
# 19850810664.17789
# 1155041132.178031
# 537012875.6838046
# 21087285.625737295
# 241.97296110563477
# 241.97296110563477
# 58.47756999612569
# 58.47756999612569
# 32.59157906373282
# 32.589688688176565
# 5.2060732281845214e-05
# 4.657349469918312e-05
# 4.657349469918312e-05
# 1.550255296546391e-05
# 3.931306772438459e-06
# 3.931306772438459e-06
# 9.609618345188566e-07
# 8.204801167452957e-07
# 8.204801167452957e-07
# ------------------
# Explained Variance
# Eigenvector 0: -1.031003688109501
# Eigenvector 1: -0.0599900773494704
# Eigenvector 2: -0.027891165996127905
# Eigenvector 3: -0.00109522324403541
# Eigenvector 4: -1.2567497597107233e-08
# Eigenvector 5: -1.2567497597107233e-08
# Eigenvector 6: -3.037185299766395e-09
# Eigenvector 7: -3.037185299766395e-09
# Eigenvector 8: -1.6927287648084847e-09
# Eigenvector 9: -1.6926305832176477e-09
# Eigenvector 10: -2.7039100768374935e-15
# Eigenvector 11: -2.4189160642016883e-15
# Eigenvector 12: -2.4189160642016883e-15
# Eigenvector 13: -8.05165569955735e-16
# Eigenvector 14: -2.0418268301697948e-16
# Eigenvector 15: -2.0418268301697948e-16
# Eigenvector 16: -4.9910062227800945e-17
# Eigenvector 17: -4.2613777376428725e-17
# Eigenvector 18: -4.2613777376428725e-17

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.20, random_state=0)
df_train=X_train
df_train['Void']=y_train

LDA_model.LDA_model(df_train)
# Out:
# Pairs:
# 0.0001075467729079209
# 7.016541692922448e-07
# 2.073244065340847e-07
# 1.047131232839087e-07
# 6.542171984046166e-14
# 6.540432104965982e-14
# 2.318223419865069e-14
# 2.318223419865069e-14
# 1.2142209037080657e-14
# 1.2053048018308192e-14
# 1.0600215041610408e-16
# 4.1014848465742135e-18
# 2.778179218664274e-19
# 5.73078221374521e-20
# 5.73078221374521e-20
# 2.6461749699416113e-20
# 1.8375361506071e-20
# 1.0060551439173128e-20
# 1.2889080895046066e-21
# ------------------
# Explained Variance
# Eigenvector 0: 0.9963903124688848
# Eigenvector 1: 0.006500626639766935
# Eigenvector 2: 0.001920801755583949
# Eigenvector 3: 0.0009701373533334749
# Eigenvector 4: 6.06113657449302e-10
# Eigenvector 5: 6.059524625930093e-10
# Eigenvector 6: 2.1477681712213609e-10
# Eigenvector 7: 2.1477681712213609e-10
# Eigenvector 8: 1.124941188786545e-10
# Eigenvector 9: 1.1166806735751027e-10
# Eigenvector 10: 9.820798236866176e-13
# Eigenvector 11: 3.7999092463363815e-14
# Eigenvector 12: 2.5739041581001097e-15
# Eigenvector 13: 5.309406992187085e-16
# Eigenvector 14: 5.309406992187085e-16
# Eigenvector 15: 2.4516059699949163e-16
# Eigenvector 16: 1.7024250656445618e-16
# Eigenvector 17: 9.320815233265552e-17
# Eigenvector 18: 1.1941367456415626e-17

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.30, random_state=0)
df_train=X_train
df_train['Void']=y_train

LDA_model.LDA_model(df_train)
# Out:
# Pairs:
# 0.00035006322492485474
# 1.1808977435755682e-06
# 1.1808977435755682e-06
# 1.3312687211944686e-10
# 1.3312687211944686e-10
# 1.0128226095537896e-10
# 6.443341822509242e-12
# 6.443341822509242e-12
# 2.0779704736579133e-12
# 2.0708724463130143e-12
# 7.106538120555297e-17
# 4.779339724070879e-18
# 4.779339724070879e-18
# 2.4919145674360804e-18
# 2.266512307809956e-19
# 1.469228080143886e-19
# 2.9939626757892044e-20
# 1.8856251976319666e-20
# 1.8856251976319666e-20
# ------------------
# Explained Variance
# Eigenvector 0: 1.0029710342417828
# Eigenvector 1: 0.0033834066159392265
# Eigenvector 2: 0.0033834066159392265
# Eigenvector 3: 3.8142366037928534e-07
# Eigenvector 4: 3.8142366037928534e-07
# Eigenvector 5: 2.9018522023434083e-07
# Eigenvector 6: 1.8460908634669286e-08
# Eigenvector 7: 1.8460908634669286e-08
# Eigenvector 8: 5.953622222202721e-09
# Eigenvector 9: 5.9332855649353996e-09
# Eigenvector 10: 2.0361041609503646e-13
# Eigenvector 11: 1.3693352985230587e-14
# Eigenvector 12: 1.3693352985230587e-14
# Eigenvector 13: 7.139619225869951e-15
# Eigenvector 14: 6.493816064152014e-16
# Eigenvector 15: 4.209505889672663e-16
# Eigenvector 16: 8.578044272037409e-17
# Eigenvector 17: 5.402531085826779e-17
# Eigenvector 18: 5.402531085826779e-17

# %%
X_train, X_test, y_train, y_test = train_test_split(void_dataset.drop('Void', axis=1),void_dataset['Void'], test_size=0.40, random_state=0)
df_train=X_train
df_train['Void']=y_train

LDA_model.LDA_model(df_train)
# Out:
# Pairs:
# 0.00014402767754103328
# 4.7445065442740674e-07
# 1.1652031946676511e-08
# 1.6496746114661085e-11
# 1.0892666165403406e-12
# 1.0892666165403406e-12
# 1.980005923935375e-14
# 1.963298015076329e-14
# 1.9942692615290874e-15
# 1.8611432058766283e-15
# 1.2974396316627539e-16
# 3.9393853411347603e-17
# 2.145249201342125e-19
# 1.803324281390394e-19
# 5.7382821858847e-20
# 3.5240138450319804e-20
# 3.5240138450319804e-20
# 2.45890258927972e-21
# 2.4169715786868472e-21
# ------------------
# Explained Variance
# Eigenvector 0: 1.0033863791502475
# Eigenvector 1: 0.0033053183413011226
# Eigenvector 2: 8.117530147209286e-05
# Eigenvector 3: 1.1492659351557542e-07
# Eigenvector 4: 7.588508715543734e-09
# Eigenvector 5: 7.588508715543734e-09
# Eigenvector 6: 1.3793952722368554e-10
# Eigenvector 7: 1.3677555037843828e-10
# Eigenvector 8: 1.3893320003068304e-11
# Eigenvector 9: 1.2965881102211075e-11
# Eigenvector 10: 9.038771411204844e-13
# Eigenvector 11: 2.7444208370246367e-13
# Eigenvector 12: 1.4945140165135186e-15
# Eigenvector 13: 1.2563078514006625e-15
# Eigenvector 14: 3.9976442606990266e-16
# Eigenvector 15: 2.4550472189864993e-16
# Eigenvector 16: 2.4550472189864993e-16
# Eigenvector 17: 1.7130244740894586e-17
# Eigenvector 18: 1.6838127242291537e-17

# %%
LDA_model.LDA_model(void_dataset)
# Out:
# Pairs:
# 0.001351911440929381
# 0.0002919222841996992
# 2.266412034879627e-06
# 3.13174090424443e-07
# 1.7325441709969645e-11
# 1.732468358631856e-11
# 1.2197672459287295e-12
# 1.2197321751626508e-12
# 1.1123515006253133e-12
# 1.1123515006253133e-12
# 5.52108534478692e-17
# 1.6337082249133387e-17
# 3.0902531024520434e-18
# 1.5441946557739648e-18
# 3.039705544536823e-19
# 2.090341070848283e-19
# 5.156164982777498e-20
# 2.296976010066989e-20
# 2.296976010066989e-20
# ------------------
# Explained Variance
# Eigenvector 0: -0.8211251887284267
# Eigenvector 1: -0.17730801992675252
# Eigenvector 2: -0.0013765753832200342
# Eigenvector 3: -0.00019021596113414133
# Eigenvector 4: -1.0523142391725135e-08
# Eigenvector 5: -1.0522681921899056e-08
# Eigenvector 6: -7.408633285398021e-10
# Eigenvector 7: -7.408420272263111e-10
# Eigenvector 8: -6.756210564024811e-10
# Eigenvector 9: -6.756210564024811e-10
# Eigenvector 10: -3.35340178984455e-14
# Eigenvector 11: -9.92283173213579e-15
# Eigenvector 12: -1.8769607129185387e-15
# Eigenvector 13: -9.379143409601925e-16
# Eigenvector 14: -1.8462590916611856e-16
# Eigenvector 15: -1.269633242490429e-16
# Eigenvector 16: -3.1317561316645735e-17
# Eigenvector 17: -1.3951393579998915e-17
# Eigenvector 18: -1.3951393579998915e-17
